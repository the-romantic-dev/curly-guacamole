# %% [markdown]
# # EMCAD + stride-2 RGB refinement
#
# RGB-ветка 24 канала на stride 2; concat RGB, 64 каналов EMCAD и coarse logits; две 3x3 свёртки ширины 32 и residual-поправка к logits.
#
# Полный forward 640×640: 97.9027 GFLOPS (FlopCounterMode, meta и CPU SDPA math).
# Родитель: pvt_v2_b2_emcad_mixed_original. Новый запуск с нуля, прежние fold/seed и 192 000 показов.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.config import load_experiment_config
from src.training.engine import run_experiment

cfg = load_experiment_config(project_root / "configs" / "emcad_stride2_rgb_mixed_original.yaml")
cfg
# Out:
# ExperimentConfig(paths=PathsConfig(data_path=WindowsPath('D:/Challenges/AIIJC2026/data'), runs_path=WindowsPath('D:/Projects/aiijc2026_final/runs'), run_name='pvt_v2_b2_emcad_640_stride2_rgb_mixed_original'), seed=42, model=ModelConfig(encoder_name='pvt_v2_b2', decoder_channels=(128, 64, 32, 16, 16), forensic_channels=(64, 96, 128), aux_weight=0.4, norm='batch', use_forensics=True, dct_aux_weight=0.0, decoder_name='emcad', decoder_embed_dim=128, decoder_kwargs={'kernel_sizes': [1, 3, 5], 'expansion_factor': 2, 'lgag_kernel_size': 3, 'activation': 'relu', 'rgb_refinement_channels': 32, 'rgb_detail_channels': 24}), augmentation=AugmentationConfig(crop_scale_range=(0.35, 1.0), jpeg_recompression_probability=0.3, jpeg_recompression_quality_range=(60, 100), full_frame=False, full_frame_probability=0.5, foreground_crop_probability=0.5, final_full_frame_epochs=2), dataset=DatasetConfig(fold=0, n_folds=5, image_size=640, resize_mode='stretch'), train=TrainConfig(device='cuda', workers=10, encoder_lr=0.0001, fmap_lr=0.0003, lr=0.0003, weight_decay=0.0001, epochs=8, epoch_size=24000, val_frac=0.25, val_keep_negatives=True, negative_fraction=0.25, batch_size=4, accum_steps=4, warmup_frac=0.05, min_lr_factor=0.02, amp='bf16', ema_decay=0.999, grad_clip=1.0, resume=False), eval=EvalConfig(n_bins=256, mask_thresholds=(0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6, 0.625, 0.65, 0.675, 0.7, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95), cls_thresholds=(0.0, 0.2, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 0.95), min_areas=(0.0,), resolution='original'))

# %%
run = run_experiment(cfg)
run.summary
# Out:
# [13:59:02] Эксперимент pvt_v2_b2_emcad_640_stride2_rgb_mixed_original: device=cuda, amp=bf16, seed=42
# [13:59:02] Подготовка метаданных и train/val разбиения
# [13:59:02] Метаданные загружены из кеша: D:\Challenges\AIIJC2026\data\train_stage1\.cache\metadata_v1.parquet
# [13:59:02] Метаданные готовы: 103699 строк; построение 5 фолдов, val fold=0
# [13:59:12] Разбиение готово: train=82959, val=20740; создание датасетов и аугментаций
# [13:59:12] Создание модели pvt_v2_b2, загрузка pretrained-весов и перенос на cuda
# [13:59:13] Модель готова; подсчёт GFLOPS
# [13:59:18] Подсчёт завершён: 97.91 GFLOPS; создание оптимизатора
# [13:59:18] Создание DataLoader: batch_size=4, workers=10
# [13:59:18] DataLoader готовы: train=6000 батчей, val=2593; настройка scheduler, AMP scaler и EMA
# [13:59:18] Создание папки эксперимента и сохранение конфигурации
# [13:59:18] pvt_v2_b2_emcad_640_stride2_rgb_mixed_original, 97.905942336 GFLOPS
# [13:59:18] Результаты: D:\Projects\aiijc2026_final\runs\pvt_v2_b2_emcad_640_stride2_rgb_mixed_original__0907-135918; проверка возобновления обучения
# [13:59:18] Полные кадры: p=0.50; валидация: original
# [13:59:18] Эпоха 1/8: обучение
# [13:59:18] Обучение, батчи: начало, всего 6000; ожидание первого элемента
# [14:00:21] Обучение, батчи: 1/6000, прошло 00:01:03, 15824.25 мс/изобр., 0.06 изобр./с
# [14:00:51] Обучение, батчи: 102/6000, прошло 00:01:34, 229.21 мс/изобр., 4.36 изобр./с, осталось ~00:29:25
# [14:01:21] Обучение, батчи: 201/6000, прошло 00:02:04, 153.63 мс/изобр., 6.51 изобр./с, осталось ~00:29:06
# [14:01:52] Обучение, батчи: 296/6000, прошло 00:02:34, 129.96 мс/изобр., 7.69 изобр./с, осталось ~00:29:11
# [14:02:22] Обучение, батчи: 388/6000, прошло 00:03:04, 118.54 мс/изобр., 8.44 изобр./с, осталось ~00:29:10
# [14:02:52] Обучение, батчи: 490/6000, прошло 00:03:34, 109.26 мс/изобр., 9.15 изобр./с, осталось ~00:28:20
# [14:03:22] Обучение, батчи: 582/6000, прошло 00:04:04, 104.88 мс/изобр., 9.53 изобр./с, осталось ~00:28:07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 run = run_experiment(cfg)
#       2 run.summary
#
# File D:\Projects\aiijc2026_final\src\training\engine.py:389, in run_experiment(config, arm)
#     388 def run_experiment(config: ExperimentConfig, *, arm: str = "baseline") -> Run:
# --> 389     return ExperimentRunner(config, arm=arm).run()
#
# File D:\Projects\aiijc2026_final\src\training\engine.py:110, in ExperimentRunner.run(self)
#     107 run.info(f"Полные кадры: p={train_ds.augmentations.full_frame_probability:.2f}; "
#     108          f"валидация: {cfg.eval.resolution}")
#     109 run.info(f"Эпоха {epoch + 1}/{cfg.train.epochs}: обучение")
# --> 110 train_result = train_one_epoch(
#     111     model=model,
#     112     loader=train_loader,
#     113     optimizer=optimizer,
#     114     scheduler=scheduler,
#     115     scaler=scaler,
#     116     ema=ema,
#     117     amp=self.amp,
#     118     config=cfg,
#     119     device=self.device,
#     120 )
#     121 state.seen_total += train_result.seen
#     122 run.info(f"Обучение завершено: loss={train_result.loss:.5f}, примеров={train_result.seen}; валидация EMA")
#
# File D:\Projects\aiijc2026_final\src\training\engine.py:353, in train_one_epoch(model, loader, optimizer, scheduler, scaler, ema, amp, config, device)
#     351 with amp.autocast():
#     352     model_kwargs = {"valid_mask": batch["valid_mask"]} if "valid_mask" in batch else {}
# --> 353     loss = compute_loss(
#     354         model(images, batch.get("fmap"), **model_kwargs),
#     355         batch,
#     356         config.model.aux_weight,
#     357         dct_aux_weight=config.model.dct_aux_weight,
#     358     )
#     360 scaler.scale(loss / config.train.accum_steps).backward()
#     361 is_accum_boundary = (step + 1) % config.train.accum_steps == 0
#
# File D:\Projects\aiijc2026_final\src\losses.py:38, in compute_loss(out, batch, aux_weight, dct_aux_weight)
#      33 total = bce + dice + 0.3 * cls
#      35 if aux_weight > 0 and "aux_logits" in out:
#      36     total = total + aux_weight * (
#      37         bce_loss(out["aux_logits"], batch["mask"], valid_mask=valid)
# ---> 38         + soft_dice_loss(out["aux_logits"], batch["mask"], valid_mask=valid)
#      39     )
#      40 if dct_aux_weight > 0:
#      41     logits = out["dct_aux_logits"]
#
# File D:\Projects\aiijc2026_final\src\losses.py:6, in soft_dice_loss(logits, targets, smooth, valid_mask)
#       5 def soft_dice_loss(logits, targets, smooth=1.0, valid_mask=None):
# ----> 6     probs = torch.sigmoid(logits).flatten(1)
#       7     targets = targets.flatten(1)
#       8     if valid_mask is not None:
#
# KeyboardInterrupt:
