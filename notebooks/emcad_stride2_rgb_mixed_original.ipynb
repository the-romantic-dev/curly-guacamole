# %% [markdown]
# # EMCAD + stride-2 RGB refinement
#
# RGB-ветка 24 канала на stride 2; concat RGB, 64 каналов EMCAD и coarse logits; две 3x3 свёртки ширины 32 и residual-поправка к logits.
#
# Полный forward 640×640: 97.9027 GFLOPS (FlopCounterMode, meta и CPU SDPA math).
# Родитель: pvt_v2_b2_emcad_mixed_original. Новый запуск с нуля, прежние fold/seed и 192 000 показов.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.config import load_experiment_config
from src.training.engine import run_experiment

cfg = load_experiment_config(project_root / "configs" / "emcad_stride2_rgb_mixed_original.yaml")
cfg
# Out:
# ExperimentConfig(paths=PathsConfig(data_path=WindowsPath('D:/Challenges/AIIJC2026/data'), runs_path=WindowsPath('D:/Projects/aiijc2026_final/runs'), run_name='pvt_v2_b2_emcad_640_stride2_rgb_mixed_original'), seed=42, model=ModelConfig(encoder_name='pvt_v2_b2', decoder_channels=(128, 64, 32, 16, 16), forensic_channels=(64, 96, 128), aux_weight=0.4, norm='batch', use_forensics=True, dct_aux_weight=0.0, decoder_name='emcad', decoder_embed_dim=128, decoder_kwargs={'kernel_sizes': [1, 3, 5], 'expansion_factor': 2, 'lgag_kernel_size': 3, 'activation': 'relu', 'rgb_refinement_channels': 32, 'rgb_detail_channels': 24}), augmentation=AugmentationConfig(crop_scale_range=(0.35, 1.0), jpeg_recompression_probability=0.3, jpeg_recompression_quality_range=(60, 100), full_frame=False, full_frame_probability=0.5, foreground_crop_probability=0.5, final_full_frame_epochs=2), dataset=DatasetConfig(fold=0, n_folds=5, image_size=640, resize_mode='stretch'), train=TrainConfig(device='cuda', workers=10, en
# ...

# %%
run = run_experiment(cfg)
run.summary
# Out:
# [14:05:53] Эксперимент pvt_v2_b2_emcad_640_stride2_rgb_mixed_original: device=cuda, amp=bf16, seed=42
# [14:05:53] Подготовка метаданных и train/val разбиения
# [14:05:53] Метаданные загружены из кеша: D:\Challenges\AIIJC2026\data\train_stage1\.cache\metadata_v1.parquet
# [14:05:53] Метаданные готовы: 103699 строк; построение 5 фолдов, val fold=0
# [14:06:03] Разбиение готово: train=82959, val=20740; создание датасетов и аугментаций
# [14:06:03] Создание модели pvt_v2_b2, загрузка pretrained-весов и перенос на cuda
# [14:06:03] Модель готова; подсчёт GFLOPS
# [14:06:04] Подсчёт завершён: 97.91 GFLOPS; создание оптимизатора
# [14:06:04] Создание DataLoader: batch_size=2, workers=10
# [14:06:04] DataLoader готовы: train=12000 батчей, val=5185; настройка scheduler, AMP scaler и EMA
# [14:06:04] Создание папки эксперимента и сохранение конфигурации
# [14:06:04] pvt_v2_b2_emcad_640_stride2_rgb_mixed_original, 97.905942336 GFLOPS
# ...
