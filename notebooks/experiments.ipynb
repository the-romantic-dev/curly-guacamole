# %% [markdown]
# # Experiments
# Current runs and historical results are inspected separately; scores from different protocols are not directly comparable.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if not (ROOT / 'src').is_dir():
    raise RuntimeError('Open this notebook from the project root or notebooks directory')
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.training.experiments import ExperimentRegistry

# %%
registry = ExperimentRegistry(ROOT / 'runs')
print(registry.tree())
display(registry.table())
for issue in registry.issues:
    print(issue)

# %% [markdown]
# ## Historical runs
# Original identifiers, weights and snapshots are preserved under runs/archive. Use the previous main pipeline to reproduce those checkpoints.

# %%
archive = ExperimentRegistry(ROOT / 'runs' / 'archive')
print(archive.tree())
display(archive.table())
for issue in archive.issues:
    print(issue)
