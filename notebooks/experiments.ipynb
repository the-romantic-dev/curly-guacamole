# %% [markdown]
# # История экспериментов
#
# Редактируйте `runs/<имя>/notes.md` и повторно выполняйте ячейки. `parent` задаёт происхождение эксперимента; пустой `baseline` использует `parent`. В `leaderboard_score` впишите число от 0 до 1. Связи не загружают веса и не меняют обучение.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
if not (ROOT / "src").is_dir():
    raise RuntimeError("Откройте ноутбук из корня проекта или notebooks")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.training.experiments import ExperimentRegistry

# %%
registry = ExperimentRegistry(ROOT / "runs")
print(registry.tree())
for issue in registry.issues:
    print("Внимание:", issue)
# Out:
# efficientvit_b2_1024_mixed_original
# efficientvit_b2_1024_mixed_original_bn_diagnostic_20260906_140332_037397
# pvt_v2_b2_640_letterbox
# pvt_v2_b2_emcad_640_dct_aux_mixed_original
# pvt_v2_b2_emcad_mixed_original
# pvt_v2_b2_full_frame
# pvt_v2_b2_mixed_original
# pvt_v2_b2_segformer_640_rgb_only_mixed_original
# pvt_v2_b2_segformer_672_mixed_original
# pvt_v2_b2_segformer_mixed_original

# %% [markdown]
# Пустые поля означают отсутствие данных. `notes_status=stub` отмечает незаполненное описание; введённые связи и скор при этом видны. Сравнивайте validation AIC только на одинаковых данных и протоколе оценки: совпадения одного `validation_resolution` недостаточно. Дельты автоматически не вычисляются.

# %%
table = registry.table()
display(table)
# Out:
#                                                  run parent baseline  \
# 0                efficientvit_b2_1024_mixed_original   None     None
# 1  efficientvit_b2_1024_mixed_original_bn_diagnos...   None     None
# 2                            pvt_v2_b2_640_letterbox   None     None
# 3         pvt_v2_b2_emcad_640_dct_aux_mixed_original   None     None
# 4                     pvt_v2_b2_emcad_mixed_original   None     None
# 5                               pvt_v2_b2_full_frame   None     None
# 6                           pvt_v2_b2_mixed_original   None     None
# 7    pvt_v2_b2_segformer_640_rgb_only_mixed_original   None     None
# 8             pvt_v2_b2_segformer_672_mixed_original   None     None
# 9                 pvt_v2_b2_segformer_mixed_original   None     None
#
#          series change  validation_aic validation_resolution  \
# 0  efficientvit   None        0.848001              original
# 1           NaN   None             NaN                   NaN
# 2           pvt   None        0.914389              original
# 3           pvt   None        0.925420              original
# 4           pvt   None        0.927039              original
# 5           pvt   None        0.881482                   NaN
# 6           pvt   None        0.925063              original
# 7           pvt   None        0.917749              original
# 8           pvt   None        0.922998              original
# 9           pvt   None        0.920019              original
#
#   leaderboard_score       verdict notes_status
# 0              None  inconclusive         stub
# 1              None           NaN      missing
# 2              None  inconclusive         stub
# 3              None  inconclusive         stub
# 4              None  inconclusive         stub
# 5              None  inconclusive       filled
# 6              None  inconclusive         stub
# 7              None  inconclusive         stub
# 8              None  inconclusive         stub
# 9              None  inconclusive         stub

# %% [markdown]
# Для сравнения конкретного запуска с его baseline укажите имя папки ниже.

# %%
run_name = ""  # например, pvt_v2_b2_mixed_original
if run_name:
    selected = table.loc[table["run"] == run_name]
    if selected.empty:
        raise ValueError(f"Неизвестный запуск: {run_name}")
    baseline = selected.iloc[0]["baseline"]
    display(table.loc[table["run"].isin([run_name, baseline])])
