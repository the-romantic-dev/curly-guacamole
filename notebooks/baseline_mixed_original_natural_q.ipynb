# %% [markdown]
# # Baseline 640: исправленная JPEG-таблица Q
#
# Контрольный запуск PVT v2 B2 + UNet на 18 эпох. Наследует `baseline_mixed_original_long.yaml`; единственное изменение preprocessing — `dataset.jpeg_qtable_order: natural`. Последние 4 эпохи full-frame.
#
# Новый запуск: `pvt_v2_b2_mixed_original_long_natural_q`. Старые checkpoint с legacy-признаками не используются для инициализации этого эксперимента. EMA/BN и остальные параметры обучения остаются прежними. Повторный запуск продолжает только собственный совместимый checkpoint.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.config import load_experiment_config
from src.training.engine import run_experiment

cfg = load_experiment_config(project_root / "configs" / "baseline_mixed_original_natural_q.yaml")
cfg
# Out:
# ExperimentConfig(paths=PathsConfig(data_path=WindowsPath('D:/Challenges/AIIJC2026/data'), runs_path=WindowsPath('D:/Projects/aiijc2026_final/runs'), run_name='pvt_v2_b2_mixed_original_natural_q'), seed=42, model=ModelConfig(encoder_name='pvt_v2_b2', decoder_channels=(128, 64, 32, 16, 16), forensic_channels=(64, 96, 128), aux_weight=0.4, norm='batch', use_forensics=True, dct_aux_weight=0.0, decoder_name='unet', decoder_embed_dim=128, decoder_kwargs={}), augmentation=AugmentationConfig(crop_scale_range=(0.35, 1.0), jpeg_recompression_probability=0.3, jpeg_recompression_quality_range=(60, 100), full_frame=False, full_frame_probability=0.5, foreground_crop_probability=0.5, final_full_frame_epochs=2), dataset=DatasetConfig(fold=0, n_folds=5, image_size=640, resize_mode='stretch', jpeg_qtable_order='natural'), train=TrainConfig(device='cuda', workers=10, encoder_lr=0.0001, fmap_lr=0.0003, lr=0.0003, weight_decay=0.0001, epochs=8, epoch_size=24000, val_frac=0.25, val_keep_negatives=True, ne
# ...

# %%
run = run_experiment(cfg)
run.summary
# Out:
# [10:59:29] Эксперимент pvt_v2_b2_mixed_original_natural_q: device=cuda, amp=bf16, seed=42
# [10:59:29] Подготовка метаданных и train/val разбиения
# [10:59:30] Метаданные загружены из кеша: D:\Challenges\AIIJC2026\data\train_stage1\.cache\metadata_v1.parquet
# [10:59:30] Метаданные готовы: 103699 строк; построение 5 фолдов, val fold=0
# [10:59:39] Разбиение готово: train=82959, val=20740; создание датасетов и аугментаций
# [10:59:39] Создание модели pvt_v2_b2, загрузка pretrained-весов и перенос на cuda
# [10:59:40] Модель готова; подсчёт GFLOPS
# [10:59:42] Подсчёт завершён: 97.16 GFLOPS; создание оптимизатора
# [10:59:42] Создание DataLoader: batch_size=4, workers=10
# [10:59:42] DataLoader готовы: train=6000 батчей, val=2593; настройка scheduler, AMP scaler и EMA
# [10:59:42] Создание папки эксперимента и сохранение конфигурации
# [10:59:42] pvt_v2_b2_mixed_original_natural_q, 97.162113024 GFLOPS
# ...
