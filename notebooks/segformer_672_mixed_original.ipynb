# %% [markdown]
# # PVTv2-B2 + SegFormer, 672 × 672
#
# Эксперимент на увеличение входа с 640 до 672 при embed_dim=128.
# Остальные настройки mixed/original сохранены: batch_size=4, accum_steps=4, 8 эпох.
# Отдельный запуск с resume=false; обучение начинается с pretrained encoder, без загрузки предыдущего run.
# Выполните все ячейки для запуска configs/segformer_672_mixed_original.yaml.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.config import load_experiment_config
from src.training.engine import run_experiment

cfg = load_experiment_config(project_root / "configs" / "segformer_672_mixed_original.yaml")
cfg
# Out:
# ExperimentConfig(paths=PathsConfig(data_path=WindowsPath('D:/Challenges/AIIJC2026/data'), runs_path=WindowsPath('D:/Projects/aiijc2026_final/runs'), run_name='pvt_v2_b2_segformer_672_mixed_original'), seed=42, model=ModelConfig(encoder_name='pvt_v2_b2', decoder_channels=(128, 64, 32, 16, 16), forensic_channels=(64, 96, 128), aux_weight=0.4, norm='batch', decoder_name='segformer', decoder_embed_dim=128, decoder_kwargs={'embed_dim': 128}), augmentation=AugmentationConfig(crop_scale_range=(0.35, 1.0), jpeg_recompression_probability=0.3, jpeg_recompression_quality_range=(60, 100), full_frame=False, full_frame_probability=0.5, foreground_crop_probability=0.5, final_full_frame_epochs=2), dataset=DatasetConfig(fold=0, n_folds=5, image_size=672, resize_mode='stretch'), train=TrainConfig(device='cuda', workers=10, encoder_lr=0.0001, fmap_lr=0.0003, lr=0.0003, weight_decay=0.0001, epochs=8, epoch_size=24000, val_frac=0.25, val_keep_negatives=True, negative_fraction=0.25, batch_size=4, accum_st
# ...

# %%
run = run_experiment(cfg)
run.summary
# Out:
# [18:38:04] Эксперимент pvt_v2_b2_segformer_672_mixed_original: device=cuda, amp=bf16, seed=42
# [18:38:04] Подготовка метаданных и train/val разбиения
# [18:38:04] Метаданные загружены из кеша: D:\Challenges\AIIJC2026\data\train_stage1\.cache\metadata_v1.parquet
# [18:38:04] Метаданные готовы: 103699 строк; построение 5 фолдов, val fold=0
# [18:38:13] Разбиение готово: train=82959, val=20740; создание датасетов и аугментаций
# [18:38:14] Создание модели pvt_v2_b2, загрузка pretrained-весов и перенос на cuda
# [18:38:15] Модель готова; подсчёт GFLOPS
# [18:38:17] Подсчёт завершён: 98.92 GFLOPS; создание оптимизатора
# [18:38:17] Создание DataLoader: batch_size=4, workers=10
# [18:38:17] DataLoader готовы: train=6000 батчей, val=2593; настройка scheduler, AMP scaler и EMA
# [18:38:17] Создание папки эксперимента и сохранение конфигурации
# [18:38:17] pvt_v2_b2_segformer_672_mixed_original, 98.920464064 GFLOPS
# ...
